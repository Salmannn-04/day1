# %% [markdown]
# # Day 1 py and git

# %%
print("hello")
# Out:
# hello

# %%
print("hi")
# Out:
# hi

# %%
print("asl"
      )
# Out:
# asl

# %%
print(1)
# Out:
# 1

# %% [markdown]
# # input & output

# %%
age = int(input("Enter age: "))
print(age)
# Out:
# 7

# %%
x = 10
y = 20.5
z = "hello"
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# # conditional statememt

# %%
age = int(input("Enter your age: "))

if age < 0:
    print("Invalid age")
elif age >= 100:
    print("Not valid")
elif age >= 18:
    print("Adult")
else:
    print("Minor")
# Out:
# Adult
