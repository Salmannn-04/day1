# %% [markdown]
# # Day 1 py and git

# %%
print("hello")
# Out:
# hello

# %%
print("hi")
# Out:
# hi

# %%
print("asl"
      )
# Out:
# asl

# %%
print(1)
# Out:
# 1

# %% [markdown]
# # input & output

# %%
age = int(input("Enter age: "))
print(age)
# Out:
# 7
